# %% [markdown]
# * Hash Functions
# * Collision Resolution Techniques
# * Hash Tables
# * Practical use of Hashing

# %% [markdown]
# * Hashing is a method of sorting and indexing data. The idea behind hashing is to allow large amounts of data to be indexed using keys commonly created by formulae

# %% [markdown]
# ![hashing_1.png](data:image/png;base64,...)

# %% [markdown]
# ![hashing_2.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * If the hash table is full, all the strings need to be called again to accomodate in the new hash table that is twice the size, this takes `O(n)` time complexity

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Practical uses of Hashing
# * Password Verification
# * File system

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
mydict = {'A': 1, 'B':2, 'C':3, 'D':3}

# %%
for key, value in enumerate(mydict):
  print(key, value)
# Out:
# 0 A
# 1 B
# 2 C
# 3 D

# %%
mydict.keys()
# Out:
# dict_keys(['A', 'B', 'C', 'D'])

# %%
mydict.values()
# Out:
# dict_values([1, 2, 3, 3])

# %%
mydict.items()
# Out:
# dict_items([('A', 1), ('B', 2), ('C', 3), ('D', 3)])

# %%
ord('Z')
# Out:
# 90

# %%
for key, values in mydict.items():
  if values%2==0:
    print(key)
# Out:
# B

# %%
##
