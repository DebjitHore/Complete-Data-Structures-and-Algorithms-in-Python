# %% [markdown]
# <a href="https://colab.research.google.com/github/DebjitHore/Complete-Data-Structures-and-Algorithms-in-Python/blob/main/Dictionaries_DSA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Dictionaries

# %% [markdown]
# * myDict['key']= value
# * Dictonaries are unordered collections, so the order may not always be the same as we prescribe at the onset.
# * Time complexity for accessing an element in a dictionary is O(1).

# %% [markdown]
# ## Dictionary in memory.

# %% [markdown]
# * There are 3 main elements in dictionaries. Keys, elements and hash functions.
# * Good hash function minimises the number of collusions. < overlap >
# * Python takes key value, passes it through a hash function, generates an index and stores the corresponding dict value in an array corresponding to the particular generated index

# %% [markdown]
# ## Insert/Update element in Dictionary.

# %%
# Time and Space Complexity is O(1) for updation.

# %%
# Time and Space Complexity is O(1) for insertion < time > and amortized O(1) for space.

# %% [markdown]
# ## Traversal through Dictionary

# %% [markdown]
# # Visiting all pairs one by one.

# %% [markdown]
# ## Searching for element in Dictionary

# %%
# Searching for an element in Dictionary based on key is O(n) time complexity and space complexity is O(1).

# %% [markdown]
# ## Delete/Remove element from Dictionary

# %%
# myDict.pop(key)
# myDict.popitem() random deletion of key-value pair. Returns key value pair
# myDict.clear() Clears all key-value pairs from dictionary.
# del myDict(key) 
# del myDict deletes entire dictionary.
# Time complexity is O(1) generally but O(n) in amortized case. Space Complexity is O(1)

# %% [markdown]
# ## Dictionary methods.

# %%
#myDict.copy() returns a shallow copy of the dictionary. Copy of references of the original dictionary. Does not modify the original one.
# myDict.fromkeys(sequence, value)
# myDict.get(key, value) If key exists it'll return corresponding value from myDict else it returns the value
# in method checks whether a key exists in a dictionary or not. key in myDict or value in myDict.values() takes same amount of time no matter how long the dictionary is since it uses a hash table and not linear search like it does in case of a list. Time complexity is O(1) in dictionary
# all(collections) and any(collections) collections being list, arrays and dictionaries.
#len(myDict), sorted(myDict), sorted(myDict, key= based_on_which_sorting_takes_places {example:len})

# %% [markdown]
# ## Dictonary versus List.

# %% [markdown]
# ![Screenshot 2021-10-06 at 11.59.50 AM.png](data:image/png;base64,...)

# %% [markdown]
# ## Time and Space Complexity

# %% [markdown]
# ![Screenshot 2021-10-06 at 12.02.02 PM.png](data:image/png;base64,...)

# %%
# If linear search is being used time complexity is O(n), if we are using in operator time complexity is O(1)
